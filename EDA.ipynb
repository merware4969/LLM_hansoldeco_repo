# %%
import pandas as pd

OUTPUT_FILE = "open/main_submission.csv"

pd.read_csv(OUTPUT_FILE).head()
# Out:
#          ID                                    재발방지대책 및 향후조치계획     vec_0  \
# 0  TEST_000  A:                                            ... -0.620284
# 1  TEST_001                                                ... -0.620284
# 2  TEST_002  A:                                            ... -0.620284
# 3  TEST_003  ### :                                         ... -0.620284
# 4  TEST_004                                                ... -0.620284
#
#       vec_1     vec_2     vec_3     vec_4     vec_5     vec_6     vec_7  ...  \
# 0 -0.377644 -0.321682  0.148727 -0.193202  0.662165  1.092194 -0.043897  ...
# 1 -0.377644 -0.321682  0.148727 -0.193202  0.662165  1.092194 -0.043897  ...
# 2 -0.377644 -0.321682  0.148727 -0.193202  0.662165  1.092194 -0.043897  ...
# 3 -0.377644 -0.321682  0.148727 -0.193202  0.662165  1.092194 -0.043897  ...
# 4 -0.377644 -0.321682  0.148727 -0.193202  0.662165  1.092194 -0.043897  ...
#
# ...

# %%
SAMPLE_FILE = "open/sample_submission.csv"

pd.read_csv(SAMPLE_FILE).head()
# Out:
#          ID 재발방지대책 및 향후조치계획     vec_0     vec_1     vec_2     vec_3     vec_4  \
# 0  TEST_000         안전교육 실시 -0.620284 -0.377644 -0.321682  0.148727 -0.193202
# 1  TEST_001         안전교육 실시 -0.620284 -0.377644 -0.321682  0.148727 -0.193202
# 2  TEST_002         안전교육 실시 -0.620284 -0.377644 -0.321682  0.148727 -0.193202
# 3  TEST_003         안전교육 실시 -0.620284 -0.377644 -0.321682  0.148727 -0.193202
# 4  TEST_004         안전교육 실시 -0.620284 -0.377644 -0.321682  0.148727 -0.193202
#
#       vec_5     vec_6     vec_7  ...   vec_758   vec_759   vec_760   vec_761  \
# 0  0.662165  1.092194 -0.043897  ...  1.336321  0.882164  1.780816  2.430824
# 1  0.662165  1.092194 -0.043897  ...  1.336321  0.882164  1.780816  2.430824
# 2  0.662165  1.092194 -0.043897  ...  1.336321  0.882164  1.780816  2.430824
# 3  0.662165  1.092194 -0.043897  ...  1.336321  0.882164  1.780816  2.430824
# 4  0.662165  1.092194 -0.043897  ...  1.336321  0.882164  1.780816  2.430824
#
# ...

# %%
TRAIN = "open/train.csv"

pd.read_csv(TRAIN).head()
# Out:
#             ID                 발생일시 사고인지 시간  날씨   기온   습도               공사종류  \
# 0  TRAIN_00000  2023-12-31 오후 12:44  정규작업 -  맑음   1℃  30%  건축 / 건축물 / 근린생활시설
# 1  TRAIN_00001  2023-12-30 오후 03:35  정규작업 -  맑음  10℃  90%     토목 / 터널 / 철도터널
# 2  TRAIN_00002  2023-12-30 오후 02:30  정규작업 -  맑음  14℃  70%    건축 / 건축물 / 업무시설
# 3  TRAIN_00003  2023-12-30 오후 12:00  휴일근무 -  흐림  12℃  55%       토목 / 하천 / 기타
# 4  TRAIN_00004  2023-12-30 오전 10:00  정규작업 -  맑음   0℃  10%    건축 / 건축물 / 공동주택
#
#           연면적           층 정보                   인적사고 물적사고              공종  \
# 0   4,892.77㎡  지상 14층, 지하 3층  떨어짐(5미터 이상 ~ 10미터 미만)   없음   건축 > 철근콘크리트공사
# 1           -              -                     끼임   없음       토목 > 터널공사
# 2   1,994.62㎡   지상 5층, 지하 0층              넘어짐(미끄러짐)   없음   건축 > 철근콘크리트공사
# 3           -              -                     기타   전도       토목 > 하천공사
# 4  59,388.93㎡  지상 27층, 지하 3층              넘어짐(미끄러짐)   없음  건축 > 해체 및 철거공사
#
#          사고객체   작업프로세스             장소          부위  \
# ...

# %%
TEST = "open/test.csv"

pd.read_csv(TEST).head()
# Out:
#          ID                 발생일시 사고인지 시간  날씨   기온   습도                  공사종류  \
# 0  TEST_000  2024-06-03 오전 09:39  정규작업 -  맑음  27℃  53%  건축 / 건축물 / 교정 및 군사시설
# 1  TEST_001  2024-02-15 오전 09:00  정규작업 -  맑음   5℃  71%       건축 / 건축물 / 운수시설
# 2  TEST_002  2024-02-01 오전 09:30  작업 전 -  흐림   5℃  58%       건축 / 건축물 / 공동주택
# 3  TEST_003  2024-02-06 오후 05:00  정규작업 -  맑음   1℃  87%       건축 / 건축물 / 공동주택
# 4  TEST_004  2024-06-03 오전 11:35    기타 -  흐림  22℃  60%        토목 / 교량 / 도로교량
#
#            연면적           층 정보         인적사고 물적사고             공종           사고객체  \
# 0    1,990.32㎡   지상 1층, 지하 0층          부딪힘   전도  건축 > 철근콘크리트공사  건설기계 > 콘크리트펌프
# 1     349,895㎡   지상 5층, 지하 2층       절단, 베임   없음      건축 > 수장공사     건설공구 > 공구류
# 2     171,198㎡  지상 27층, 지하 2층  떨어짐(2미터 미만)   없음      건축 > 미장공사        기타 > 기타
# 3  123,540.98㎡  지상 2층, 지하 35층  넘어짐(물체에 걸림)   없음      건축 > 조적공사      건설자재 > 자재
# 4            -              -  떨어짐(2미터 미만)   없음      토목 > 교량공사        기타 > 기타
#
# ...

# %%
from tensorflow.python.client import device_lib 
device_lib.list_local_devices()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36300\3309887829.py in <module>
# ----> 1 from tensorflow.python.client import device_lib
#       2 device_lib.list_local_devices()
#
# ModuleNotFoundError: No module named 'tensorflow'
